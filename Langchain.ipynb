# %%
#%pip install -U langchain-openrouter
# %pip install langchain langchain-core
# %pip install langchain-openai python-dotenv
# Out:
# Requirement already satisfied: langchain in c:\users\vigne\appdata\local\programs\python\python314\lib\site-packages (1.3.13)
# Requirement already satisfied: langchain-core in c:\users\vigne\appdata\local\programs\python\python314\lib\site-packages (1.4.9)
# Requirement already satisfied: langgraph<1.3.0,>=1.2.5 in c:\users\vigne\appdata\local\programs\python\python314\lib\site-packages (from langchain) (1.2.9)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\vigne\appdata\local\programs\python\python314\lib\site-packages (from langchain) (2.12.5)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\vigne\appdata\local\programs\python\python314\lib\site-packages (from langchain-core) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.17 in c:\users\vigne\appdata\local\programs\python\python314\lib\site-packages (from langchain-core) (0.0.18)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\users\vigne\appdata\local\programs\python\python314\lib\site-packages (from langchain-core) (0.10.2)
# Requirement already satisfied: packaging>=23.2.0 in c:\users\vigne\appdata\local\programs\python\python314\lib\site-packages (from langchain-core) (25.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\users\vigne\appdata\local\programs\python\python314\lib\site-packages (from langchain-core) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\vigne\appdata\local\programs\python\python314\lib\site-packages (from langchain-core) (9.1.4)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\users\vigne\appdata\local\programs\python\python314\lib\site-packages (from langchain-core) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\users\vigne\appdata\local\programs\python\python314\lib\site-packages (from langchain-core) (0.17.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\vigne\appdata\local\programs\python\python314\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core) (3.1.1)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=4.1.0 in c:\users\vigne\appdata\local\programs\python\python314\lib\site-packages (from langgraph<1.3.0,>=1.2.5->langchain) (4.1.1)
# Requirement already satisfied: langgraph-prebuilt<1.2.0,>=1.1.0 in c:\users\vigne\appdata\local\programs\python\python314\lib\site-packages (from langgraph<1.3.0,>=1.2.5->langchain) (1.1.0)
# Requirement already satisfied: langgraph-sdk<0.5.0,>=0.4.2 in c:\users\vigne\appdata\local\programs\python\python314\lib\site-packages (from langgraph<1.3.0,>=1.2.5->langchain) (0.4.2)
# Requirement already satisfied: xxhash>=3.5.0 in c:\users\vigne\appdata\local\programs\python\python314\lib\site-packages (from langgraph<1.3.0,>=1.2.5->langchain) (3.8.1)
# Requirement already satisfied: ormsgpack>=1.12.0 in c:\users\vigne\appdata\local\programs\python\python314\lib\site-packages (from langgraph-checkpoint<5.0.0,>=4.1.0->langgraph<1.3.0,>=1.2.5->langchain) (1.12.2)
# Requirement already satisfied: httpx>=0.25.2 in c:\users\vigne\appdata\local\programs\python\python314\lib\site-packages (from langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.5->langchain) (0.28.1)
# Requirement already satisfied: orjson>=3.11.5 in c:\users\vigne\appdata\local\programs\python\python314\lib\site-packages (from langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.5->langchain) (3.11.9)
# Requirement already satisfied: websockets<16,>=14 in c:\users\vigne\appdata\local\programs\python\python314\lib\site-packages (from langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.5->langchain) (15.0.1)
# Requirement already satisfied: anyio>=3.5.0 in c:\users\vigne\appdata\local\programs\python\python314\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (4.14.2)
# Requirement already satisfied: distro>=1.7.0 in c:\users\vigne\appdata\local\programs\python\python314\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (1.9.0)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\vigne\appdata\local\programs\python\python314\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in c:\users\vigne\appdata\local\programs\python\python314\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (2.34.2)
# Requirement already satisfied: sniffio>=1.1 in c:\users\vigne\appdata\local\programs\python\python314\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (1.3.1)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\vigne\appdata\local\programs\python\python314\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (0.25.0)
# Requirement already satisfied: certifi in c:\users\vigne\appdata\local\programs\python\python314\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.5->langchain) (2026.6.17)
# Requirement already satisfied: httpcore==1.* in c:\users\vigne\appdata\local\programs\python\python314\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.5->langchain) (1.0.9)
# Requirement already satisfied: idna in c:\users\vigne\appdata\local\programs\python\python314\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.5->langchain) (3.18)
# Requirement already satisfied: h11>=0.16 in c:\users\vigne\appdata\local\programs\python\python314\lib\site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.5->langchain) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\vigne\appdata\local\programs\python\python314\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\vigne\appdata\local\programs\python\python314\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\vigne\appdata\local\programs\python\python314\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\vigne\appdata\local\programs\python\python314\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core) (3.4.9)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\users\vigne\appdata\local\programs\python\python314\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core) (2.7.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.3 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Collecting langchain-openai
#   Downloading langchain_openai-1.3.5-py3-none-any.whl.metadata (3.4 kB)
# Requirement already satisfied: langchain-core<2.0.0,>=1.4.9 in c:\users\vigne\appdata\local\programs\python\python314\lib\site-packages (from langchain-openai) (1.4.9)
# Collecting openai<3.0.0,>=2.45.0 (from langchain-openai)
#   Downloading openai-2.45.0-py3-none-any.whl.metadata (34 kB)
# Collecting tiktoken<1.0.0,>=0.7.0 (from langchain-openai)
#   Downloading tiktoken-0.13.0-cp314-cp314-win_amd64.whl.metadata (6.8 kB)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\vigne\appdata\local\programs\python\python314\lib\site-packages (from langchain-core<2.0.0,>=1.4.9->langchain-openai) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.17 in c:\users\vigne\appdata\local\programs\python\python314\lib\site-packages (from langchain-core<2.0.0,>=1.4.9->langchain-openai) (0.0.18)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\users\vigne\appdata\local\programs\python\python314\lib\site-packages (from langchain-core<2.0.0,>=1.4.9->langchain-openai) (0.10.2)
# Requirement already satisfied: packaging>=23.2.0 in c:\users\vigne\appdata\local\programs\python\python314\lib\site-packages (from langchain-core<2.0.0,>=1.4.9->langchain-openai) (25.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\vigne\appdata\local\programs\python\python314\lib\site-packages (from langchain-core<2.0.0,>=1.4.9->langchain-openai) (2.12.5)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\users\vigne\appdata\local\programs\python\python314\lib\site-packages (from langchain-core<2.0.0,>=1.4.9->langchain-openai) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\vigne\appdata\local\programs\python\python314\lib\site-packages (from langchain-core<2.0.0,>=1.4.9->langchain-openai) (9.1.4)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\users\vigne\appdata\local\programs\python\python314\lib\site-packages (from langchain-core<2.0.0,>=1.4.9->langchain-openai) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\users\vigne\appdata\local\programs\python\python314\lib\site-packages (from langchain-core<2.0.0,>=1.4.9->langchain-openai) (0.17.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\vigne\appdata\local\programs\python\python314\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.4.9->langchain-openai) (3.1.1)
# Requirement already satisfied: anyio>=3.5.0 in c:\users\vigne\appdata\local\programs\python\python314\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.9->langchain-openai) (4.14.2)
# Requirement already satisfied: distro>=1.7.0 in c:\users\vigne\appdata\local\programs\python\python314\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.9->langchain-openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\vigne\appdata\local\programs\python\python314\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.9->langchain-openai) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in c:\users\vigne\appdata\local\programs\python\python314\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.9->langchain-openai) (3.11.9)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\vigne\appdata\local\programs\python\python314\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.9->langchain-openai) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in c:\users\vigne\appdata\local\programs\python\python314\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.9->langchain-openai) (2.34.2)
# Requirement already satisfied: sniffio>=1.1 in c:\users\vigne\appdata\local\programs\python\python314\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.9->langchain-openai) (1.3.1)
# Requirement already satisfied: websockets>=15.0 in c:\users\vigne\appdata\local\programs\python\python314\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.9->langchain-openai) (15.0.1)
# Requirement already satisfied: xxhash>=3.0.0 in c:\users\vigne\appdata\local\programs\python\python314\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.9->langchain-openai) (3.8.1)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\vigne\appdata\local\programs\python\python314\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.9->langchain-openai) (0.25.0)
# Requirement already satisfied: certifi in c:\users\vigne\appdata\local\programs\python\python314\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.9->langchain-openai) (2026.6.17)
# Requirement already satisfied: httpcore==1.* in c:\users\vigne\appdata\local\programs\python\python314\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.9->langchain-openai) (1.0.9)
# Requirement already satisfied: idna in c:\users\vigne\appdata\local\programs\python\python314\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.9->langchain-openai) (3.18)
# Requirement already satisfied: h11>=0.16 in c:\users\vigne\appdata\local\programs\python\python314\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.9->langchain-openai) (0.16.0)
# Collecting jiter<1,>=0.10.0 (from openai<3.0.0,>=2.45.0->langchain-openai)
#   Downloading jiter-0.16.0-cp314-cp314-win_amd64.whl.metadata (5.3 kB)
# Requirement already satisfied: tqdm>4 in c:\users\vigne\appdata\local\programs\python\python314\lib\site-packages (from openai<3.0.0,>=2.45.0->langchain-openai) (4.68.3)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\vigne\appdata\local\programs\python\python314\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.4.9->langchain-openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\vigne\appdata\local\programs\python\python314\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.4.9->langchain-openai) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\vigne\appdata\local\programs\python\python314\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.4.9->langchain-openai) (0.4.2)
# Collecting regex (from tiktoken<1.0.0,>=0.7.0->langchain-openai)
#   Downloading regex-2026.7.10-cp314-cp314-win_amd64.whl.metadata (41 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\vigne\appdata\local\programs\python\python314\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.9->langchain-openai) (3.4.9)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\users\vigne\appdata\local\programs\python\python314\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.9->langchain-openai) (2.7.0)
# Requirement already satisfied: colorama in c:\users\vigne\appdata\roaming\python\python314\site-packages (from tqdm>4->openai<3.0.0,>=2.45.0->langchain-openai) (0.4.6)
# Downloading langchain_openai-1.3.5-py3-none-any.whl (121 kB)
# Downloading openai-2.45.0-py3-none-any.whl (1.6 MB)
#    ---------------------------------------- 0.0/1.6 MB ? eta -:--:--
#    ------------------------- -------------- 1.0/1.6 MB 7.9 MB/s eta 0:00:01
#    ---------------------------------------- 1.6/1.6 MB 5.7 MB/s  0:00:00
# Downloading jiter-0.16.0-cp314-cp314-win_amd64.whl (198 kB)
# Downloading tiktoken-0.13.0-cp314-cp314-win_amd64.whl (918 kB)
#    ---------------------------------------- 0.0/918.7 kB ? eta -:--:--
#    ---------------------------------------- 918.7/918.7 kB 12.1 MB/s  0:00:00
# Downloading regex-2026.7.10-cp314-cp314-win_amd64.whl (280 kB)
# Installing collected packages: regex, jiter, tiktoken, openai, langchain-openai
#
#    ---------------------------------------- 0/5 [regex]
#    ------------------------ --------------- 3/5 [openai]
#    ------------------------ --------------- 3/5 [openai]
#    ------------------------ --------------- 3/5 [openai]
#    ------------------------ --------------- 3/5 [openai]
#    ------------------------ --------------- 3/5 [openai]
#    ------------------------ --------------- 3/5 [openai]
#    ------------------------ --------------- 3/5 [openai]
#    ------------------------ --------------- 3/5 [openai]
#    ------------------------ --------------- 3/5 [openai]
#    ------------------------ --------------- 3/5 [openai]
#    ------------------------ --------------- 3/5 [openai]
#    ------------------------ --------------- 3/5 [openai]
#    ------------------------ --------------- 3/5 [openai]
#    ------------------------ --------------- 3/5 [openai]
#    ------------------------ --------------- 3/5 [openai]
#    ------------------------ --------------- 3/5 [openai]
#    ------------------------ --------------- 3/5 [openai]
#    ------------------------ --------------- 3/5 [openai]
#    ------------------------ --------------- 3/5 [openai]
#    ------------------------ --------------- 3/5 [openai]
#    ------------------------ --------------- 3/5 [openai]
#    ------------------------ --------------- 3/5 [openai]
#    ------------------------ --------------- 3/5 [openai]
#    ------------------------ --------------- 3/5 [openai]
#    ------------------------ --------------- 3/5 [openai]
#    ------------------------ --------------- 3/5 [openai]
#    ------------------------ --------------- 3/5 [openai]
#    ------------------------ --------------- 3/5 [openai]
#    ------------------------ --------------- 3/5 [openai]
#    ------------------------ --------------- 3/5 [openai]
#    ------------------------ --------------- 3/5 [openai]
#    ------------------------ --------------- 3/5 [openai]
#    ------------------------ --------------- 3/5 [openai]
#    ------------------------ --------------- 3/5 [openai]
#    ------------------------ --------------- 3/5 [openai]
#    ------------------------ --------------- 3/5 [openai]
#    ------------------------ --------------- 3/5 [openai]
#    ------------------------ --------------- 3/5 [openai]
#    ------------------------ --------------- 3/5 [openai]
#    ------------------------ --------------- 3/5 [openai]
#    ------------------------ --------------- 3/5 [openai]
#    ------------------------ --------------- 3/5 [openai]
#    ------------------------ --------------- 3/5 [openai]
#    ------------------------ --------------- 3/5 [openai]
#    ------------------------ --------------- 3/5 [openai]
#    ------------------------ --------------- 3/5 [openai]
#    ------------------------ --------------- 3/5 [openai]
#    -------------------------------- ------- 4/5 [langchain-openai]
#    ---------------------------------------- 5/5 [langchain-openai]
#
# Successfully installed jiter-0.16.0 langchain-openai-1.3.5 openai-2.45.0 regex-2026.7.10 tiktoken-0.13.0
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.3 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# Import Libraries

# %%
from langchain_openai import ChatOpenAI

from langchain_core.prompts import PromptTemplate
from langchain_core.output_parsers import StrOutputParser
# Out:
# c:\Users\vigne\AppData\Local\Programs\Python\Python314\Lib\site-packages\langchain_core\utils\pydantic.py:41: UserWarning: Core Pydantic V1 functionality isn't compatible with Python 3.14 or greater.
#   from pydantic.v1 import BaseModel as BaseModelV1

# %% [markdown]
# API KEY

# %%
import os
from dotenv import load_dotenv
load_dotenv()
api_key = os.getenv("OPENROUTER_API_KEY")

# %%
llm = ChatOpenAI(
    model="google/gemini-2.5-flash",
    temperature=0.7,
    max_tokens = 1000,
    api_key=api_key,
    base_url="https://openrouter.ai/api/v1"
)

# %%
prompt = "Suggest me a skill that is in demand?"
response = llm.invoke(prompt)
print(" Suggested Skill:\n", response)
# Out:
#  Suggested Skill:
#  content='To give you the best suggestion, I need a little more information about your interests and career goals. However, I can give you a broad overview of highly in-demand skills right now, categorized for clarity.\n\n**Here are some of the most in-demand skills across various sectors:**\n\n---\n\n**I. Technology & Data (Consistently High Demand):**\n\n1.  **Data Science & Analytics:**\n    *   **Why:** Businesses are drowning in data and need people to extract insights, predict trends, and inform strategic decisions.\n    *   **Specific Skills:** Python/R, SQL, machine learning (ML), data visualization (Tableau, Power BI), statistical modeling, big data technologies (Spark, Hadoop).\n    *   **Roles:** Data Scientist, Data Analyst, Machine Learning Engineer, Business Intelligence Analyst.\n\n2.  **Artificial Intelligence (AI) & Machine Learning (ML):**\n    *   **Why:** AI is transforming industries, automating tasks, and creating new opportunities.\n    *   **Specific Skills:** Deep learning frameworks (TensorFlow, PyTorch), natural language processing (NLP), computer vision, reinforcement learning, model deployment.\n    *   **Roles:** AI Engineer, ML Engineer, NLP Specialist, Robotics Engineer.\n\n3.  **Cloud Computing (AWS, Azure, Google Cloud):**\n    *   **Why:** Companies are rapidly migrating to the cloud for scalability, cost-efficiency, and flexibility.\n    *   **Specific Skills:** Cloud architecture, infrastructure as code (Terraform, CloudFormation), containerization (Docker, Kubernetes), serverless computing, cloud security.\n    *   **Roles:** Cloud Engineer, DevOps Engineer, Solutions Architect, Cloud Security Engineer.\n\n4.  **Cybersecurity:**\n    *   **Why:** With increasing cyber threats, protecting data and systems is paramount for every organization.\n    *   **Specific Skills:** Network security, ethical hacking, incident response, security information and event management (SIEM), penetration testing, risk management.\n    *   **Roles:** Cybersecurity Analyst, Security Engineer, Penetration Tester, CISO.\n\n5.  **Software Development (especially Full-Stack, specific languages like Python, JavaScript, Java, Go):**\n    *   **Why:** The digital world runs on software. New applications, platforms, and features are constantly needed.\n    *   **Specific Skills:** Proficiency in specific languages/frameworks (e.g., React, Node.js, Django, Spring Boot), API development, database management, agile methodologies.\n    *   **Roles:** Full-Stack Developer, Back-End Developer, Front-End Developer, Mobile App Developer.\n\n---\n\n**II. Digital & Marketing:**\n\n6.  **Digital Marketing (SEO, SEM, Content, Social Media):**\n    *   **Why:** Reaching customers online is crucial. Businesses need experts to navigate the complex digital landscape.\n    *   **Specific Skills:** SEO best practices, Google Ads, social media strategy, content creation/strategy, email marketing, analytics (Google Analytics).\n    *   **Roles:** Digital Marketing Manager, SEO Specialist, Content Strategist, Social Media Manager.\n\n7.  **UX/UI Design:**\n    *   **Why:** User experience is paramount for product success. Intuitive and appealing interfaces drive engagement.\n    *   **Specific Skills:** User research, wireframing, prototyping, usability testing, design tools (Figma, Sketch, Adobe XD), information architecture.\n    *   **Roles:** UX Designer, UI Designer, Product Designer, Interaction Designer.\n\n---\n\n**III. Business & Soft Skills (Enhance any technical skill):**\n\n8.  **Project Management (especially Agile/Scrum):**\n    *   **Why:** Efficiently delivering projects on time and within budget is always a valuable skill. Agile methodologies are particularly sought after.\n    *   **Specific Skills:** Agile/Scrum, Waterfall, risk management, stakeholder communication, project planning tools (Jira, Asana, Trello).\n    *   **Roles:** Project Manager, Scrum Master, Product Owner.\n\n9.  **Critical Thinking & Problem Solving: ...

# %% [markdown]
# prompt template

# %%
template = "Give me 3 career skills that are in high demand in {year}."
prompt_template = PromptTemplate.from_template(template)

# %%
parser = StrOutputParser()

# %% [markdown]
# Build chain

# %%
chain = prompt_template | llm | parser

# %%
response = chain.invoke({"year": "2026"})
print("\n Career Skills in 2026:\n", response)
# Out:
#  Career Skills in 2026:
#  Here are 3 career skills that are projected to be in high demand in 2026, along with a brief explanation of why:
#
# 1.  **AI and Machine Learning Proficiency (including Prompt Engineering):**
#     *   **Why it's in demand:** Artificial Intelligence and Machine Learning are no longer niche technologies; they are becoming foundational to almost every industry. From automating tasks and analyzing vast datasets to powering new products and services, AI is transforming work. In 2026, the demand won't just be for AI developers, but for professionals across various roles who can effectively *utilize* and *interact* with AI tools. This includes **prompt engineering** – the skill of crafting effective queries and instructions for AI models to achieve desired outcomes – which will be crucial for maximizing AI's utility in operations, content creation, data analysis, and more. Understanding AI ethics and limitations will also be key.
#
# 2.  **Advanced Data Literacy & Analytics:**
#     *   **Why it's in demand:** The sheer volume of data being generated continues to explode, and businesses that can effectively collect, interpret, and leverage this data will have a significant competitive advantage. In 2026, it won't be enough to just know how to use a spreadsheet. Demand will be high for individuals who can not only perform complex data analysis (using tools like Python, R, SQL, and advanced visualization software) but also translate those insights into actionable business strategies and communicate them clearly to non-technical stakeholders. This includes understanding data governance, privacy regulations, and ethical data use.
#
# 3.  **Complex Problem-Solving & Critical Thinking (with a focus on adaptability):**
#     *   **Why it's in demand:** As technology advances rapidly and global challenges become more interconnected, the ability to tackle novel, complex problems that don't have clear-cut solutions will be paramount. Automation and AI will increasingly handle routine tasks, leaving humans to focus on higher-level strategic thinking. This skill involves breaking down intricate issues, analyzing information from various sources, evaluating different approaches, anticipating potential consequences, and devising innovative solutions. The "adaptability" aspect is crucial because the nature of these problems, and the tools available to solve them, will constantly evolve. This skill is foundational for innovation, resilience, and navigating an ever-changing professional landscape.
